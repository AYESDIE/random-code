# %%
# !wget https://a2.udemycdn.com/2017-11-09_20-20-02-f47567d42ebb30b9e7cd7ab8e9ba48ed/original.zip?nva=20190713161638&download=True&filename=FULL-TENSORFLOW-NOTES-AND-DATA.zip&token=07646eae1173e7b084f4a
# Out:
# --2019-07-13 11:47:06--  https://a2.udemycdn.com/2017-11-09_20-20-02-f47567d42ebb30b9e7cd7ab8e9ba48ed/original.zip?nva=20190713161638
# Resolving a2.udemycdn.com (a2.udemycdn.com)... 8.252.43.250, 8.252.193.122, 8.240.38.250
# Connecting to a2.udemycdn.com (a2.udemycdn.com)|8.252.43.250|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2019-07-13 11:47:06 ERROR 403: Forbidden.

# %% [markdown]
# **Pandas**

# %%
import pandas as pd

# %%
pwd
# Out:
# '/content'

# %%
pd.read_csv('')
