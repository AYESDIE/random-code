# %% [markdown]
# # TF Variable and Placeholders

# %%
import tensorflow as tf

# %%
sess = tf.InteractiveSession()

# %%
tensor = tf.random_uniform((4, 4), 0, 1)

# %%
tensor
# Out:
# <tf.Tensor 'random_uniform:0' shape=(4, 4) dtype=float32>

# %%
var = tf.Variable(initial_value = tensor)

# %%
print(var)
# Out:
# <tf.Variable 'Variable:0' shape=(4, 4) dtype=float32_ref>

# %%
# sess.run(var)
init = tf.global_variables_initializer()

# %%
sess.run(init)

# %%
sess.run(var)
# Out:
# array([[0.3262707 , 0.03566337, 0.96133125, 0.7354764 ],
#        [0.16540325, 0.9227929 , 0.72425497, 0.81218123],
#        [0.19274724, 0.2104342 , 0.27664125, 0.01891565],
#        [0.78840494, 0.41581225, 0.7625202 , 0.14664328]], dtype=float32)

# %%
ph = tf.placeholder(tf.float32, shape = (4, 4))
